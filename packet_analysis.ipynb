# %%
# By Ismael Valenzuela (@aboutsecurity / @thinkredactblue)

from scapy.all import *
import pandas as pd
import numpy as np
import binascii
import matplotlib.pyplot as plt
import datetime
import socket

# %matplotlib inline

# %%
def pcap_to_dataframe(pcap): 
    # Conversts pcap to dataframe    
    ip_fields = [field.name for field in IP().fields_desc]
    # Change flag field in IP header to ip_flags
    new_ip_fields = ['ip_flags' if ip_fields == 'flags' else ip_fields for ip_fields in ip_fields]  

    tcp_fields = [field.name for field in TCP().fields_desc]
    # Change flag field in TCP header to tcp_flags
    new_tcp_fields = ['tcp_flags' if tcp_fields == 'flags' else tcp_fields for tcp_fields in tcp_fields]  

    udp_fields = [field.name for field in UDP().fields_desc]

    dataframe_fields = new_ip_fields + ['time'] + new_tcp_fields + ['payload','payload_raw','payload_hex']

    my_df = pd.DataFrame(columns=dataframe_fields)
    for packet in pcap[IP]:
        field_values = []
        for field in ip_fields:
            if field == 'options':
                field_values.append(len(packet[IP].fields[field]))
            else:
                field_values.append(packet[IP].fields[field])
        
        field_values.append(packet.time)
        
        layer_type = type(packet[IP].payload)
        for field in tcp_fields:
            try:
                if field == 'options':
                    field_values.append(len(packet[layer_type].fields[field]))
                else:
                    field_values.append(packet[layer_type].fields[field])
            except:
                field_values.append(None)
        
        field_values.append(len(packet[layer_type].payload))
        field_values.append(packet[layer_type].payload.original)
        field_values.append(binascii.hexlify(packet[layer_type].payload.original))
        df_append = pd.DataFrame([field_values], columns=dataframe_fields)
        my_df = pd.concat([my_df, df_append], axis=0)

    my_df = my_df.reset_index()
    my_df["len"] = pd.to_numeric(my_df["len"])
    my_df["time"] = pd.to_numeric(my_df["len"])

    my_df = my_df.drop(columns="index")

    return my_df

# %%
# Read pcap files
pcap1 = rdpcap("../pcaps/generated_traffic_1.pcap")
pcap2 = rdpcap("../pcaps/generated_traffic_2.pcap")
pcap3 = rdpcap("../pcaps/generated_traffic_3.pcap")
pcap4 = rdpcap("../pcaps/generated_traffic_4.pcap")

# Create dataframes
df1 = pcap_to_dataframe(pcap1)
df2 = pcap_to_dataframe(pcap2)
df3 = pcap_to_dataframe(pcap3)
df4 = pcap_to_dataframe(pcap4)

# %%
protocol_stats = df1.groupby("proto")['src'].count()
print(protocol_stats)
protocol_stats.plot(kind='barh',title="Protocol Distribution",figsize=(8,5))
plt.show()
# Out:
# proto
# 6     43
# 17     7
# Name: src, dtype: int64

# %%
# Graph - Group by Source Address and Payload Sum

source_addresses = df1.groupby("src")['payload'].sum()
source_addresses.plot(kind='barh',title="Addresses Sending Payloads",figsize=(8,5))
plt.show()

# %%
# Graph - Group by Dest Address and Payload Sum

dst_addresses = df1.groupby("dst")['payload'].sum()
dst_addresses.plot(kind='barh',title="Addresses Receiving Payloads",figsize=(8,5))
plt.show()

# %%
# Graph - Group by Destination Port and Payload Sum

destination_ports = df1.groupby("dport")['payload'].sum()
destination_ports.plot(kind='barh',title="Destination Ports (Bytes Received)",figsize=(8,5))
plt.show()

# %%
# Graph - Group by Destination Port, Protocol and Payload Sum

destination_payloads_proto = df1.groupby(["dport","proto"])['payload'].sum()
destination_payloads_proto.plot(kind='barh',title="Destination Ports by Protocol (Bytes Received)",figsize=(8,5))
plt.show()

# %%
# UDP length statistics
df1[df1['proto'] == 17].describe()
# Out:
#         len  time
# count   7.0   7.0
# mean   64.0  64.0
# std     0.0   0.0
# min    64.0  64.0
# 25%    64.0  64.0
# 50%    64.0  64.0
# 75%    64.0  64.0
# max    64.0  64.0

# %%
# TCP length statistics
df1[df1['proto'] == 6].describe()
# Out:
#               len        time
# count   43.000000   43.000000
# mean    96.116279   96.116279
# std     53.731790   53.731790
# min     52.000000   52.000000
# 25%     52.000000   52.000000
# 50%     52.000000   52.000000
# 75%    164.000000  164.000000
# max    164.000000  164.000000

# %%
# Packet length visualizations
# Length does not include 14 bytes in Ethernet frame header (Wireshark will show total length inc. Ethernet frame header)
df1['len'].plot(figsize=(16,4))
df1['len'].plot(subplots=True, figsize=(16,4))
df1['len'].plot(y=['len'], figsize=(16,4))
plt.xticks(df1.index)
plt.show()

# UDP length 
udp_df = df1[df1['proto'] == 17]
destination_ports = udp_df.groupby("len")['payload'].sum()
destination_ports.plot(kind='barh',title="UDP Payload Length (Bytes Received)",figsize=(8,5))
plt.show()

# TCP length
tcp_df = df1[df1['proto'] == 6]
# Select PUSH ACK packets only
tcp_df_push_ack = tcp_df[tcp_df['tcp_flags'] == 'PA']
destination_ports = tcp_df_push_ack.groupby("len")['payload'].sum()
destination_ports.plot(kind='barh',title="TCP Payload Length (Bytes Received)",figsize=(8,5))
plt.show()

# TCP segment size by IP address

# %%
# Geocoordinates from several pcaps - payload
# Splitting the payload column into sets of 4 characters, and add them to new column
# Looking for similarities
def return_list_of_bytes(x,n):
    return [x[index : index + n] for index in range(0, len(x), n)]

df1['payload_array_raw'] = df1['payload_raw'].apply(lambda x: return_list_of_bytes(x,4))

df1['payload_array_raw'].iloc[10][0]
# Out:
# b'\xc0\xa8\x07\x8c'

# %%
# Looking for similarities
# Create a Pandas Series with all values in Payload Bytes column
listbytes = pd.Series(df1['payload_array_raw'].explode())
listbytes.dropna(inplace=True)

# Visualize TOP 20 occurrences 
listbytes.value_counts().nlargest(20).plot.bar(figsize=(16,4))
# Out:
# <AxesSubplot:>

# %%
# Search IP in payload - visualization
import socket

# Convert an IP string to long
def long2ip(ip):
    return socket.inet_ntoa(ip)

# Take a list of bytes strings
def searchPayload(payload):
    payloadIps = []
    for p in payload:
        if len(p) % 4  == 0 and p != b'':
            ip = long2ip(p)
            payloadIps.append(ip)
    return payloadIps

# Creates a new column that is a pandas Series
df1['payload_ips'] = df1['payload_array_raw'].apply(lambda x: searchPayload(x))

# %%
# Create a Pandas Series with all values in Payload IPs column
listIPs = pd.Series(df1['payload_ips'].explode())
listIPs.dropna(inplace=True)

# Visualize TOP 20 occurrences 
listIPs.value_counts().nlargest(20).plot.bar(figsize=(16,4))
# Out:
# <AxesSubplot:>

# %%
# Additional filter - match IPs in payload that are shown in IP headers only
list_matchingIPs = []

def matchingIPs(pcap):
    for i in pcap:
        for j in listIPs:
            if (j == (i[IP].src)) or (j == (i[IP].dst)):
                    if j not in list_matchingIPs:
                        list_matchingIPs.append(j)

matchingIPs(pcap1)
list_matchingIPs
# Out:
# ['192.168.7.140', '192.168.7.135']

# %%
# Find in what positions in the payload these IPs are found
# Payload_IPs is a column of panda series
# Iterate over the list of unique IPs and search for occurrances in row and position of the payload_ips column in the DF
for i in listIPs: 
        for j in range(df1['payload_ips'].str.len().max()): # Max length of all series under payload_IPs column 
            if ((df1['payload_ips'].str[j] == i).values.sum()) > 0: # Counts occurrances for position i inside series
                print ('IP address:',i,'found in position:',j,'times:',(df1['payload_ips'].str[j] == i).values.sum())
# Out:
# IP address: 192.168.7.140 found in position: 0 times: 24
# IP address: 0.1.0.5 found in position: 1 times: 1
# IP address: 18.52.17.33 found in position: 2 times: 2
# IP address: 192.168.7.135 found in position: 0 times: 2
# IP address: 0.2.0.5 found in position: 1 times: 1
# IP address: 18.52.17.33 found in position: 2 times: 2
# IP address: 192.168.7.140 found in position: 0 times: 24
# IP address: 0.3.0.0 found in position: 1 times: 1
# IP address: 0.5.18.52 found in position: 2 times: 7
# IP address: 17.33.144.0 found in position: 3 times: 7
# IP address: 16.52.49.46 found in position: 4 times: 7
# IP address: 52.48.51.51 found in position: 5 times: 7
# IP address: 56.44.50.46 found in position: 6 times: 7
# IP address: 49.55.52.48 found in position: 7 times: 7
# IP address: 51.0.214.78 found in position: 8 times: 1
# IP address: 192.168.7.140 found in position: 0 times: 24
# IP address: 0.4.0.16 found in position: 1 times: 1
# IP address: 0.100.31.139 found in position: 2 times: 1
# IP address: 8.0.146.193 found in position: 3 times: 1
# IP address: 170.95.0.3 found in position: 4 times: 1
# IP address: 237.89.221.79 found in position: 5 times: 1
# IP address: 220.70.16.231 found in position: 6 times: 1
# IP address: 53.15.252.15 found in position: 7 times: 1
# IP address: 22.15.85.35 found in position: 8 times: 1
# IP address: 245.176.119.189 found in position: 9 times: 1
# IP address: 107.159.169.99 found in position: 10 times: 1
# IP address: 201.248.124.119 found in position: 11 times: 1
# IP address: 110.252.113.178 found in position: 12 times: 1
# IP address: 239.8.84.85 found in position: 13 times: 1
# IP address: 43.68.81.64 found in position: 14 times: 1
# IP address: 1.18.5.82 found in position: 15 times: 1
# IP address: 120.168.250.183 found in position: 16 times: 1
# IP address: 119.119.103.191 found in position: 17 times: 1
# IP address: 184.47.32.9 found in position: 18 times: 1
# IP address: 42.149.110.121 found in position: 19 times: 1
# IP address: 216.185.153.223 found in position: 20 times: 1
# IP address: 204.206.236.204 found in position: 21 times: 1
# IP address: 126.153.179.139 found in position: 22 times: 1
# IP address: 208.61.189.59 found in position: 23 times: 1
# IP address: 190.252.116.113 found in position: 24 times: 1
# IP address: 138.119.239.46 found in position: 25 times: 1
# IP address: 47.182.158.161 found in position: 26 times: 1
# IP address: 121.172.239.43 found in position: 27 times: 1
# IP address: 192.168.7.140 found in position: 0 times: 24
# IP address: 0.4.0.15 found in position: 1 times: 1
# IP address: 0.100.133.148 found in position: 2 times: 1
# IP address: 242.30.133.212 found in position: 3 times: 1
# IP address: 179.123.78.18 found in position: 4 times: 1
# IP address: 202.104.228.7 found in position: 5 times: 1
# IP address: 216.247.131.192 found in position: 6 times: 1
# IP address: 243.241.150.135 found in position: 7 times: 1
# IP address: 48.33.116.203 found in position: 8 times: 1
# IP address: 241.158.195.153 found in position: 9 times: 1
# IP address: 249.246.229.250 found in position: 10 times: 1
# IP address: 230.248.179.227 found in position: 11 times: 1
# IP address: 108.125.56.190 found in position: 12 times: 1
# IP address: 56.95.135.123 found in position: 13 times: 1
# IP address: 72.254.63.109 found in position: 14 times: 1
# IP address: 113.58.152.254 found in position: 15 times: 1
# IP address: 145.122.104.219 found in position: 16 times: 1
times: 1
# IP address: 192.168.7.140 found in position: 0 times: 24
# IP address: 0.4.0.1 found in position: 1 times: 1
# IP address: 0.100.218.24 found in position: 2 times: 1
# IP address: 121.62.67.108 found in position: 3 times: 1
# IP address: 231.217.53.122 found in position: 4 times: 1
# IP address: 194.132.175.240 found in position: 5 times: 1
# IP address: 252.138.176.47 found in position: 6 times: 1
# IP address: 94.169.250.211 found in position: 7 times: 1
# IP address: 137.107.0.2 found in position: 8 times: 1
# IP address: 171.190.163.192 found in position: 9 times: 1
# IP address: 213.112.191.156 found in position: 10 times: 1
# IP address: 177.235.98.219 found in position: 11 times: 1
# IP address: 240.239.131.250 found in position: 12 times: 1
# IP address: 178.40.149.136 found in position: 13 times: 1
# IP address: 81.162.74.201 found in position: 14 times: 1
# IP address: 100.240.193.20 found in position: 15 times: 1
# IP address: 222.203.225.218 found in position: 16 times: 1
# IP address: 36.234.44.34 found in position: 17 times: 1
# IP address: 43.101.196.18 found in position: 18 times: 1
# IP address: 81.157.51.106 found in position: 19 times: 1
# IP address: 249.71.141.127 found in position: 20 times: 1
# IP address: 161.2.175.77 found in position: 21 times: 1
# IP address: 154.212.11.141 found in position: 22 times: 1
# IP address: 94.63.137.100 found in position: 23 times: 1
# IP address: 66.250.86.146 found in position: 24 times: 1
# IP address: 212.208.233.172 found in position: 25 times: 1
# IP address: 96.138.212.115 found in position: 26 times: 1
# IP address: 154.183.169.144 found in position: 27 times: 1
# IP address: 192.168.7.140 found in position: 0 times: 24
# IP address: 0.4.0.0 found in position: 1 times: 1
# IP address: 0.49.177.11 found in position: 2 times: 1
# IP address: 63.140.21.249 found in position: 3 times: 1
# IP address: 33.205.133.252 found in position: 4 times: 1
# IP address: 50.249.98.246 found in position: 5 times: 1
# IP address: 53.51.217.254 found in position: 6 times: 1
# IP address: 175.255.207.179 found in position: 7 times: 1
# IP address: 105.155.182.105 found in position: 8 times: 1
# IP address: 105.155.182.105 found in position: 11 times: 1
# IP address: 155.182.105.155 found in position: 9 times: 1
# IP address: 182.105.155.182 found in position: 10 times: 1
# IP address: 105.155.182.105 found in position: 8 times: 1
# IP address: 105.155.182.105 found in position: 11 times: 1
# IP address: 155.246.47.179 found in position: 12 times: 1
# IP address: 56.194.140.0 found in position: 13 times: 1
# IP address: 40.0.0.174 found in position: 14 times: 1
# IP address: 192.168.7.135 found in position: 0 times: 2
# IP address: 0.3.0.17 found in position: 1 times: 1
# IP address: 0.5.18.52 found in position: 2 times: 7
# IP address: 17.33.144.0 found in position: 3 times: 7
# IP address: 16.52.49.46 found in position: 4 times: 7
# IP address: 52.48.51.51 found in position: 5 times: 7
# IP address: 56.44.50.46 found in position: 6 times: 7
# IP address: 49.55.52.48 found in position: 7 times: 7
# IP address: 51.0.133.105 found in position: 8 times: 1

# %%
# Finding the heartbeat

df1['proto'].plot(figsize=(16,4))
df1['proto'].plot(subplots=True, figsize=(16,4))
df1['proto'].plot(y=["proto"], figsize=(16,4))
plt.xticks(df1.index)
plt.yticks([6,17],['tcp','udp'])
plt.show()

df2['proto'].plot(figsize=(16,4))
df2['proto'].plot(subplots=True, figsize=(16,4))
df2['proto'].plot(y=["proto"], figsize=(16,4))
plt.xticks(df2.index)
plt.yticks([6,17],['tcp','udp'])
plt.show()

df3['proto'].plot(figsize=(16,4))
df3['proto'].plot(subplots=True, figsize=(16,4))
df3['proto'].plot(y=["proto"], figsize=(16,4))
plt.xticks(df3.index)
plt.yticks([6,17],['tcp','udp'])
plt.show()

df4['proto'].plot(figsize=(16,4))
df4['proto'].plot(subplots=True, figsize=(16,4))
df4['proto'].plot(y=["proto"], figsize=(16,4))
plt.xticks(df4.index)
plt.yticks([6,17],['tcp','udp'])
plt.show()

# Notice the heartbeat packet
# Negotiation changes across runs

# %%
# Geolocation show UDP heartbeats payload in ASCII strings
# Based on our previous exploration we suspect the UDP packets carry the payloads
# Let's see what's in those payloads, using scapy's hexdump

for packet in pcap1[UDP]:
    print('\n')
    hexdump(packet.payload)

# Notice there's a string that repeats
# Google that! Those are coordinates!
# Out:
# 0000  45 00 00 40 00 01 00 00 40 11 EA 48 C0 A8 07 8C  E..@....@..H....
# 0010  C0 A8 07 87 10 E1 10 E1 00 2C 50 07 C0 A8 07 8C  .........,P.....
# 0020  00 03 00 00 00 05 12 34 11 21 90 00 10 34 31 2E  .......4.!...41.
# 0030  34 30 33 33 38 2C 32 2E 31 37 34 30 33 00 D6 4E  40338,2.17403..N
#
#
# 0000  45 00 00 40 00 01 00 00 40 11 EA 48 C0 A8 07 8C  E..@....@..H....
# 0010  C0 A8 07 87 10 E1 10 E1 00 2C 63 2C C0 A8 07 8C  .........,c,....
# 0020  00 03 00 01 00 05 12 34 11 21 90 00 10 34 31 2E  .......4.!...41.
# 0030  34 30 33 33 38 2C 32 2E 31 37 34 30 33 00 C3 28  40338,2.17403..(
#
#
# 0000  45 00 00 40 00 01 00 00 40 11 EA 48 C0 A8 07 8C  E..@....@..H....
# 0010  C0 A8 07 87 10 E1 10 E1 00 2C 29 D1 C0 A8 07 8C  .........,).....
# 0020  00 03 00 02 00 05 12 34 11 21 90 00 10 34 31 2E  .......4.!...41.
# 0030  34 30 33 33 38 2C 32 2E 31 37 34 30 33 00 FC 82  40338,2.17403...
#
#
# 0000  45 00 00 40 00 01 00 00 40 11 EA 48 C0 A8 07 8C  E..@....@..H....
# 0010  C0 A8 07 87 10 E1 10 E1 00 2C 3C 6E C0 A8 07 8C  .........,<n....
# 0020  00 03 00 03 00 05 12 34 11 21 90 00 10 34 31 2E  .......4.!...41.
# 0030  34 30 33 33 38 2C 32 2E 31 37 34 30 33 00 E9 E4  40338,2.17403...
#
#
# 0000  45 00 00 40 00 01 00 00 40 11 EA 48 C0 A8 07 8C  E..@....@..H....
# 0010  C0 A8 07 87 10 E1 10 E1 00 2C A2 7B C0 A8 07 8C  .........,.{....
# 0020  00 03 00 04 00 05 12 34 11 21 90 00 10 34 31 2E  .......4.!...41.
# 0030  34 30 33 33 38 2C 32 2E 31 37 34 30 33 00 83 D6  40338,2.17403...
#
#
# 0000  45 00 00 40 00 01 00 00 40 11 EA 48 C0 A8 07 8C  E..@....@..H....
# 0010  C0 A8 07 87 10 E1 10 E1 00 2C 8F A0 C0 A8 07 8C  .........,......
# 0020  00 03 00 05 00 05 12 34 11 21 90 00 10 34 31 2E  .......4.!...41.
# 0030  34 30 33 33 38 2C 32 2E 31 37 34 30 33 00 96 B0  40338,2.17403...
#
#
# 0000  45 00 00 40 00 01 00 00 40 11 EA 48 C0 A8 07 87  E..@....@..H....
# 0010  C0 A8 07 8C 10 E1 10 E1 00 2C A0 E0 C0 A8 07 87  .........,......
# 0020  00 03 00 11 00 05 12 34 11 21 90 00 10 34 31 2E  .......4.!...41.
# 0030  34 30 33 33 38 2C 32 2E 31 37 34 30 33 00 85 69  40338,2.17403..i

# %%
# Extract all coordinates from UDP payload and plot them in a map
import folium

COORD_map = folium.Map(zoom_start=12, 
tiles='cartodbpositron', width=640, height=480)

def packet_add_coordinates(pcap):
    for packet in pcap[UDP]:
        # Put in var decoded the UDP payload as a str
        decoded = (str(packet.payload[2]))
        print (re.findall(r'\d{1,2}\.\d+', decoded))
        folium.Marker(re.findall(r'\d{1,2}\.\d+', decoded)).add_to(COORD_map)

packet_add_coordinates(pcap1)
packet_add_coordinates(pcap2)
packet_add_coordinates(pcap3)
packet_add_coordinates(pcap4)

# Visualize map 

COORD_map
# Out:
# ['41.40338', '2.17403']
# ['41.40338', '2.17403']
# ['41.40338', '2.17403']
# ['41.40338', '2.17403']
# ['41.40338', '2.17403']
# ['41.40338', '2.17403']
# ['41.40338', '2.17403']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['23.01667', '55.43333']
# ['41.40338', '2.17403']
# ['67.42809', '36.172826']
# ['67.42809', '36.172826']
# ['67.42809', '36.172826']
# ['41.40338', '2.17403']
# ['63.2', '31.51667']
# ['63.2', '31.51667']
# ['63.2', '31.51667']
# ['63.2', '31.51667']
# ['41.40338', '2.17403']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_04d480363c4d4e11bdf357e043124c4c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20640.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20480.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_04d480363c4d4e11bdf357e043124c4c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_04d480363c4d4e11bdf357e043124c4c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_04d480363c4d4e11bdf357e043124c4c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%20L ...
