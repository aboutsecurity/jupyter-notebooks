# %%
# By Ismael Valenzuela (@aboutsecurity / @thinkredactblue)

#  Begin by importing the pandas and numpy libraries, two common libraries used for manipulating data, and loading the DNS Analytics data into a pandas DataFrame. A Pandas DataFrame is simply a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects. It is generally the most commonly used pandas object.

import pandas as pd
import numpy as np
data = pd.read_csv('data.csv')

# %%
# Download Cisco Umbrella Top 1 Million file from http://s3-us-west-1.amazonaws.com/umbrella-static/top-1m.csv.zip

top = pd.read_csv('top-1m.csv',names=["Num", "Name"])

# %%
print(data)
# Out:
#                    Computer        TimeGenerated [UTC]  EventId      SubType
# 0      USDC01.tyrellcorp.us   2/5/2022, 5:43:07.550 PM      257  LookupQuery  \
# 1      USDC01.tyrellcorp.us   2/5/2022, 5:43:07.550 PM      257  LookupQuery
# 2      USDC01.tyrellcorp.us   2/5/2022, 5:43:07.550 PM      257  LookupQuery
# 3      USDC01.tyrellcorp.us   2/5/2022, 5:43:07.550 PM      257  LookupQuery
# 4      USDC01.tyrellcorp.us   2/3/2022, 9:28:24.910 AM      257  LookupQuery
# ...                     ...                        ...      ...          ...
# 22140  USDC01.tyrellcorp.us  2/2/2022, 10:16:05.826 PM      257  LookupQuery
# 22141  USDC01.tyrellcorp.us  2/2/2022, 10:16:05.812 PM      257  LookupQuery
# 22142  USDC01.tyrellcorp.us  2/2/2022, 10:15:59.468 PM      257  LookupQuery
# 22143  USDC01.tyrellcorp.us  2/2/2022, 10:15:54.061 PM      257  LookupQuery
# 22144  USDC01.tyrellcorp.us  2/2/2022, 10:15:20.311 PM      257  LookupQuery
#
#             ClientIP                            Name  Result  Message
# 0      192.168.57.49                     airhobi.com     NaN      NaN  \
# 1      192.168.57.49                  yudaisuzuki.jp     NaN      NaN
# 2      192.168.57.49                  yudaisuzuki.jp     NaN      NaN
# 3      192.168.57.49               zspwolawiazowa.pl     NaN      NaN
# 4      192.168.59.43                  www.sf-cdn.net     NaN      NaN
# ...              ...                             ...     ...      ...
# 22140  192.168.57.57  s-usc1c-nss-220.firebaseio.com     NaN      NaN
# 22141  192.168.57.57  s-usc1c-nss-220.firebaseio.com     NaN      NaN
# 22142   192.168.32.9            www2.embratel.com.br     NaN      NaN
# 22143   192.168.32.9                 www.tuya.com.co     NaN      NaN
# 22144  192.168.61.64   easylist-msie.adblockplus.org     NaN      NaN
#
#        TaskCategory QueryType  ...  IndicatorThreatType  Description
# 0               NaN         A  ...                  NaN          NaN  \
# 1               NaN         A  ...                  NaN          NaN
# 2               NaN         A  ...                  NaN          NaN
# 3               NaN         A  ...                  NaN          NaN
# 4               NaN      AAAA  ...                  NaN          NaN
# ...             ...       ...  ...                  ...          ...
# 22140           NaN      AAAA  ...                  NaN          NaN
# 22141           NaN         A  ...                  NaN          NaN
# 22142           NaN         A  ...                  NaN          NaN
# 22143           NaN         A  ...                  NaN          NaN
# 22144           NaN      AAAA  ...                  NaN          NaN
#
#        Confidence  Severity  ReportReferenceLink  RemoteIPLongitude
# 0             NaN       NaN                  NaN                NaN  \
# 1             NaN       NaN                  NaN                NaN
# 2             NaN       NaN                  NaN                NaN
# 3             NaN       NaN                  NaN                NaN
# 4             NaN       NaN                  NaN                NaN
# ...           ...       ...                  ...                ...
# 22140         NaN       NaN                  NaN                NaN
# 22141         NaN       NaN                  NaN                NaN
# 22142         NaN       NaN                  NaN                NaN
# 22143         NaN       NaN                  NaN                NaN
# 22144         NaN       NaN                  NaN                NaN
#
#        RemoteIPLatitude  RemoteIPCountry       Type  _ResourceId
# 0                   NaN              NaN  DnsEvents          NaN
# 1                   NaN              NaN  DnsEvents          NaN
# 2                   NaN              NaN  DnsEvents          NaN
# 3                   NaN              NaN  DnsEvents          NaN
# 4                   NaN              NaN  DnsEvents          NaN
# ...                 ...              ...        ...          ...
# 22140               NaN              NaN  DnsEvents          NaN
# 22141               NaN              NaN  DnsEvents          NaN
# 22142               NaN              NaN  DnsEvents          NaN
# 22143               NaN              NaN  DnsEvents          NaN
# 22144               NaN              NaN  DnsEvents          NaN
#
# [22145 rows x 22 columns]

# %%
data.describe()
# Out:
#             EventId  Result  Message  TaskCategory    ResultCode  MaliciousIP
# count  22145.000000     0.0      0.0           0.0  22145.000000          0.0  \
# mean     257.001897     NaN      NaN           NaN      0.024520          NaN
# std        0.043510     NaN      NaN           NaN      0.263001          NaN
# min      257.000000     NaN      NaN           NaN      0.000000          NaN
# 25%      257.000000     NaN      NaN           NaN      0.000000          NaN
# 50%      257.000000     NaN      NaN           NaN      0.000000          NaN
# 75%      257.000000     NaN      NaN           NaN      0.000000          NaN
# max      258.000000     NaN      NaN           NaN      3.000000          NaN
#
#        IndicatorThreatType  Description  Confidence  Severity
# count                  0.0          0.0         0.0       0.0  \
# mean                   NaN          NaN         NaN       NaN
# std                    NaN          NaN         NaN       NaN
# min                    NaN          NaN         NaN       NaN
# 25%                    NaN          NaN         NaN       NaN
# 50%                    NaN          NaN         NaN       NaN
# 75%                    NaN          NaN         NaN       NaN
# max                    NaN          NaN         NaN       NaN
#
#        ReportReferenceLink  RemoteIPLongitude  RemoteIPLatitude
# count                  0.0                0.0               0.0  \
# mean                   NaN                NaN               NaN
# std                    NaN                NaN               NaN
# min                    NaN                NaN               NaN
# 25%                    NaN                NaN               NaN
# 50%                    NaN                NaN               NaN
# 75%                    NaN                NaN               NaN
# max                    NaN                NaN               NaN
#
#        RemoteIPCountry  _ResourceId
# count              0.0          0.0
# mean               NaN          NaN
# std                NaN          NaN
# min                NaN          NaN
# 25%                NaN          NaN
# 50%                NaN          NaN
# 75%                NaN          NaN
# max                NaN          NaN

# %%
top.describe()
# Out:
#                   Num
# count  1000000.000000
# mean    500000.500000
# std     288675.278932
# min          1.000000
# 25%     250000.750000
# 50%     500000.500000
# 75%     750000.250000
# max    1000000.000000

# %%
# Start reducing the dataset by removing DNS queries to domains in Cisco Umbrella's Top 1 million dataset

reduced = (data[~data.Name.isin(top.Name)])

# %%
reduced.describe()
# Out:
#            EventId  Result  Message  TaskCategory   ResultCode  MaliciousIP
# count  3963.000000     0.0      0.0           0.0  3963.000000          0.0  \
# mean    257.010346     NaN      NaN           NaN     0.020691          NaN
# std       0.101199     NaN      NaN           NaN     0.202398          NaN
# min     257.000000     NaN      NaN           NaN     0.000000          NaN
# 25%     257.000000     NaN      NaN           NaN     0.000000          NaN
# 50%     257.000000     NaN      NaN           NaN     0.000000          NaN
# 75%     257.000000     NaN      NaN           NaN     0.000000          NaN
# max     258.000000     NaN      NaN           NaN     2.000000          NaN
#
#        IndicatorThreatType  Description  Confidence  Severity
# count                  0.0          0.0         0.0       0.0  \
# mean                   NaN          NaN         NaN       NaN
# std                    NaN          NaN         NaN       NaN
# min                    NaN          NaN         NaN       NaN
# 25%                    NaN          NaN         NaN       NaN
# 50%                    NaN          NaN         NaN       NaN
# 75%                    NaN          NaN         NaN       NaN
# max                    NaN          NaN         NaN       NaN
#
#        ReportReferenceLink  RemoteIPLongitude  RemoteIPLatitude
# count                  0.0                0.0               0.0  \
# mean                   NaN                NaN               NaN
# std                    NaN                NaN               NaN
# min                    NaN                NaN               NaN
# 25%                    NaN                NaN               NaN
# 50%                    NaN                NaN               NaN
# 75%                    NaN                NaN               NaN
# max                    NaN                NaN               NaN
#
#        RemoteIPCountry  _ResourceId
# count              0.0          0.0
# mean               NaN          NaN
# std                NaN          NaN
# min                NaN          NaN
# 25%                NaN          NaN
# 50%                NaN          NaN
# 75%                NaN          NaN
# max                NaN          NaN

# %%
# Continue reducing the dataset based on duplicated records

reduced = reduced.drop_duplicates(subset='Name', keep='first')
reduced.describe()
# Out:
#           EventId  Result  Message  TaskCategory  ResultCode  MaliciousIP
# count  211.000000     0.0      0.0           0.0  211.000000          0.0  \
# mean   257.009479     NaN      NaN           NaN    0.018957          NaN
# std      0.097126     NaN      NaN           NaN    0.194253          NaN
# min    257.000000     NaN      NaN           NaN    0.000000          NaN
# 25%    257.000000     NaN      NaN           NaN    0.000000          NaN
# 50%    257.000000     NaN      NaN           NaN    0.000000          NaN
# 75%    257.000000     NaN      NaN           NaN    0.000000          NaN
# max    258.000000     NaN      NaN           NaN    2.000000          NaN
#
#        IndicatorThreatType  Description  Confidence  Severity
# count                  0.0          0.0         0.0       0.0  \
# mean                   NaN          NaN         NaN       NaN
# std                    NaN          NaN         NaN       NaN
# min                    NaN          NaN         NaN       NaN
# 25%                    NaN          NaN         NaN       NaN
# 50%                    NaN          NaN         NaN       NaN
# 75%                    NaN          NaN         NaN       NaN
# max                    NaN          NaN         NaN       NaN
#
#        ReportReferenceLink  RemoteIPLongitude  RemoteIPLatitude
# count                  0.0                0.0               0.0  \
# mean                   NaN                NaN               NaN
# std                    NaN                NaN               NaN
# min                    NaN                NaN               NaN
# 25%                    NaN                NaN               NaN
# 50%                    NaN                NaN               NaN
# 75%                    NaN                NaN               NaN
# max                    NaN                NaN               NaN
#
#        RemoteIPCountry  _ResourceId
# count              0.0          0.0
# mean               NaN          NaN
# std                NaN          NaN
# min                NaN          NaN
# 25%                NaN          NaN
# 50%                NaN          NaN
# 75%                NaN          NaN
# max                NaN          NaN

# %%
# Extract coordinates from our reduced dataframe, uses IP-API to get latitude and, and plot them in a map

import folium
import json
import urllib.request

api = "http://ip-api.com/json/"
TIME_PERIOD = 60 

COORD_map = folium.Map(zoom_start=12, 
tiles='cartodbpositron', width=1280, height=1080)

def add_coordinates(domain,computername):
    response = urllib.request.urlopen(api + domain)
    data = response.read()
    value = json.loads(data)

    print (domain+","+str(value['lat'])+","+str(value['lon'])+","+value['status'])

    if (value['status']=='success'):
    
        html = "\
            <font size=1><h1>"+domain+"</h1><ul>\
                <font size=2><li>Country: "+value['country']+"</li>\
                    <li>City: "+value['city']+"</li>\
                        <li>ISP: "+value['isp']+"</li>\
                            <li>Org: "+value['org']+"</li>\
                                <li>Source: "+computername+"</li>\
                            </ul></font>"
        iframe = folium.IFrame(html=html, width=250, height=200)

        folium.Marker(
            location = [(value['lat']),(value['lon'])],
            popup = folium.Popup(iframe, max_width=2650),
            icon=folium.DivIcon(html=f"""
                <div><svg>
                    <circle cx="25" cy="25" r="20" fill="#69b3a2" opacity=".4"/>
                    <rect x="17", y="17" width="15" height="15", fill="red", opacity=".3" 
                </svg></div>""")
        ).add_to(COORD_map)

# Iterate over reduced dataframe

for i in range(10):
    add_coordinates(reduced.iloc[i].Name,reduced.iloc[i].Computer)

# Visualize map 

COORD_map
# COORD_map.save('map.html')
# Out:
# /Users/ivalenzuela/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# airhobi.com,41.0016,29.1418,success
# yudaisuzuki.jp,34.704,135.495,success
# zspwolawiazowa.pl,50.8498,16.4757,success
# i2-wdcymnhaxkxcjgkzxliefkcfaaiqhk.init.cedexis-radar.net,39.018,-77.539,success
# www2.embratel.com.br,-22.9068,-43.1729,success
# ftp.kuehne-nagel.com,53.5412,9.99418,success
# emailweb.sktelecom.com,37.4331,127.1377,success
# portal.cttexpresso.pt,38.731,-9.1373,success
# cmedimage.ddns.net,-23.4736,-47.4425,success
# nwgtw-prd.poreskaupravars.org,44.776,17.1995,success
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5026760ce303dc3270b8a7a3ef0fb566 {
#                     position: relative;
#                     width: 1280.0px;
#                     height: 1080.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5026760ce303dc3270b8a7a3ef0fb566&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5026760ce303dc3270b8a7a3ef0fb566 = L.map(
#                 &quot;map_5026760ce303dc3270b8a7a3ef0fb566&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d6125707f0aeaf96b9da1a70ec0f60e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5026760ce303dc3270b8a7a3ef0fb566);
#
#
#             var marker_a34f9e34aedf72ab71a0ab521507124d = L.marker(
#                 [41.0016, 29.1418],
#                 {}
#             ).addTo(map_5026760ce303dc3270b8a7a3ef0fb566);
#
#
#             var div_icon_117af624d0a41ae669bd06f988da0972 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv\u003e\u003csvg\u003e\n                    \u003ccircle cx=\&quot;25\&quot; cy=\&quot;25\&quot; r=\&quot;20\&quot; fill=\&quot;#69b3a2\&quot; opacity=\&quot;.4\&quot;/\u003e\n                    \u003crect x=\&quot;17\&quot;, y=\&quot;17\&quot; width=\&quot;15\&quot; height=\&quot;15\&quot;, fill=\&quot;red\&quot;, opacity=\&quot;.3\&quot; \n                \u003c/svg\u003e\u003c/div\u003e&quot;});
#             marker_a34f9e34aedf72ab71a0ab521507124d.setIcon(div_icon_117af624d0a41ae669bd06f988da0972);
#
#
#         var popup_7f04421dd1c1a95bf0b9a9042857bae3 = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var i_frame_38ef30301d93d0ade232622bfbaec95f = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;250&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_7f04421dd1c1a95bf0b9a9042857bae3.setContent(i_frame_38ef30301d93d0ade232622bfbaec95f);
#
#
#
#         marker_a34f9e34aedf72ab71a0ab521507124d.bindPopup(popup_7f04421dd1c1a95bf0b9a9042857bae3)
#         ;
#
#
#
#
#             var marker_57b002dd3f3c4d2ade6f69c9dfa5fedf = L.marker(
#                 [34.704, 135.495],
#                 {}
#             ).addTo(map_5026760ce303dc3270b8a7a3ef0fb566);
#
#
#             var div_icon_cadd7e84c8f67df223d7cba0413ceabb = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv\u003e\u003csvg\u003e\n                    \u003ccircle cx=\&quot;25\&quot; cy=\&quot;25\&quot; r=\&quot;20\&quot; fill=\&quot;#69b3a2\&quot; opacity=\&quot;.4\&quot;/\u003e\n                    \u003crect x=\&quot;17\&quot;, y=\&quot;17\&quot; width=\&quot;15\&quot; height=\&quot;15\&quot;, fill=\&quot;red\&quot;, opacity=\&quot;.3\&quot; \n                \u003c/svg\u003e\u003c/div\u003e&quot;});
#             marker_57b002dd3f3c4d2ade6f69c9dfa5fedf.setIcon(div_icon_cadd7e84c8f67df223d7cba0413ceabb);
#
#
#         var popup_6d59efbaca23d4d6ae70ee9784a7fa72 = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var i_frame_7eb54cbbe21d112f297efae9db84b4e1 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;250&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_6d59efbaca23d4d6ae70ee9784a7fa72.setContent(i_frame_7eb54cbbe21d112f297efae9db84b4e1);
#
#
#
#         marker_57b002dd3f3c4d2ade6f69c9dfa5fedf.bindPopup(popup_6d59efbaca23d4d6ae70ee9784a7fa72)
#         ;
#
#
#
#
#             var marker_16602c255ae38d5044d0e5e6b95eb18c = L.marker(
#                 [50.8498, 16.4757],
#                 {}
#             ).addTo(map_5026760ce303dc3270b8a7a3ef0fb566);
#
#
#             var div_icon_7ca5e568c808efd47a10800577b98df0 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv\u003e\u003csvg\u003e\n                    \u003ccircle cx=\&quot;25\&quot; cy=\&quot;25\&quot; r=\&quot;20\&quot; fill=\&quot;#69b3a2\&quot; opacity=\&quot;.4\&quot;/\u003e\n                    \u003crect x=\&quot;17\&quot;, y=\&quot;17\&quot; width=\&quot;15\&quot; height=\&quot;15\&quot;, fill=\&quot;red\&quot;, opacity=\&quot;.3\&quot; \n                \u003c/svg\u003e\u003c/div\u003e&quot;});
#             marker_16602c255ae38d5044d0e5e6b95eb18c.setIcon(div_icon_7ca5e568c808efd47a10800577b98df0);
#
#
#         var popup_2fee31b422a50026bcdb2aeb8d
